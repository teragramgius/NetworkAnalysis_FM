# %%
import pandas as pd
import numpy as np
import spacy
from spacy import displacy
import networkx as nx

import matplotlib.pyplot as plt

# %%
NER = spacy.load('it_core_news_sm')

# %%
script= 'data/FiloAct2.txt'
script_text = open(script, encoding='utf-8').read()
script_doc = NER(script_text)

# %%
# quick test - identified entities
displacy.render(script_doc[0:2000], style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">﻿</br></br></br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ATTO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  SECONDO </br>L’indomani. La medesima scena del primo atto. Per pulire il pavimento la serva ha spostato tutte le sedie: qualcuna portandola sul terrazzo, altre adagiandole, capovolte, sul tavolo, altre, ancora, confinandole nello «studio» di
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Domenico
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# . Il tappeto, sul quale fa centro il tavolo da pranzo, è piegato su sé stesso ai quattro lati. Luci normali di una bella mattina di sole.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lucia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  è la serva di casa: simpatica e sana ragazza sui ventitre anni. Ha completato il suo lavoro.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strizza
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  per l’ultima volta lo strofinaccio nel secchio dell’acqua sudicia, quindi va a riporre tutti gli arnesi di pulizia sul terrazzo. </br>SCENA
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PRIMA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  </br>(
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LUCIA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  e
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ALFREDO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , poi
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ROSALIA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ALFREDO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Stanco
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , assonnato, entra dalla comune, mentre
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lucia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  si accinge a rimettere a posto il tappeto)
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Buongiorno
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lucia LUCIA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  (Fermandolo con il tono risentito della voce e col gesto) Non cominciate a camminare con i piedi!
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ALFREDO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Non ti preoccupare, camminerò con le mani! LUCIA Io proprio adesso ho finito di buttare il sangue… (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mostra
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  il pavimento ancora in parte bagnato)
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Voi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  vi presentate con questi piedoni!
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ALFREDO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  I piedoni?... Io sono stanco morto! (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Siede
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  presso il tavolo) Tutta la notte dietro dietro al signor
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Domenico
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , senza chiudere occhio, seduto sul parapetto di via
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Caracciolo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . Adesso inizia anche a fare freschetto…
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Il Signore
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  doveva fare capitare proprio me alle sue dipendenze! Non che mi lamento, per l’amor di
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dio!
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  Io ho vissuto, lui mi ha

# %%
# Read characters
character_df = pd.read_csv("data/characters.csv")
#character_df

# %%
import re 
character_df['character'] = character_df['character'].apply(lambda x: re.sub("[\(].*?[\)]", "", x)) 
character_df['character_firstname'] = character_df['character'].apply(lambda x: x.split(' ', 1)[0])

# %%
sent_entity_df = []

# Loop through sentences, store named entity list for each sentence
for sent in script_doc.sents:
    entity_list = [ent.text for ent in sent.ents]
    sent_entity_df.append({"sentence": sent, "entities": entity_list})
    
sent_entity_df = pd.DataFrame(sent_entity_df)

# %%
sent_entity_df
# Out:
#                                               sentence    entities
# 0      (﻿, \n\n\n, ATTO, SECONDO, \n, L’, indomani, .)      [ATTO]
# 1           (La, medesima, scena, del, primo, atto, .)          []
# 2    (Per, pulire, il, pavimento, la, serva, ha, sp...          []
# 3    (qualcuna, portandola, sul, terrazzo, ,, altre...  [Domenico]
# 4    (Il, tappeto, ,, sul, quale, fa, centro, il, t...          []
# ..                                                 ...         ...
# 720  ((, Prende, dal, seno, un, medaglione, ,, lo, ...          []
# 721  (Ne, strappa, un, pezzetto, ,, poi, a, Domenic...  [Domenico]
# 722                                         (Tieni, .)     [Tieni]
# 723  ((, Poggia, il, biglietto, sul, tavolo, e, ,, ...    [Poggia]
# 724  ((, Esce, per, il, fondo, a, sinistra, dicendo...          []
#
# [725 rows x 2 columns]

# %%
# Function to filter out non-character entities
def filter_entity(ent_list, character_df):
    return [ent for ent in ent_list 
            if ent in list(character_df.character) 
            or ent in list(character_df.character_firstname)]

# %%
filter_entity(["Filomena", "Thu", "2"], character_df)
# Out:
# ['Filomena']

# %%
sent_entity_df['character_entities'] = sent_entity_df['entities'].apply(lambda x: filter_entity(x, character_df))

# Filter out sentences that don't have any character entities
sent_entity_df_filtered = sent_entity_df[sent_entity_df['character_entities'].map(len) > 0]
sent_entity_df_filtered.head(10)
# Out:
#                                              sentence  \
# 3   (qualcuna, portandola, sul, terrazzo, ,, altre...
# 6                  (Lucia, è, la, serva, di, casa, :)
# 11  (SCENA, PRIMA, \n, (, LUCIA, e, ALFREDO, ,, po...
# 15  (..., Io, sono, stanco, morto, !, (, Siede, pr...
# 21  (Non, posso, più, fare, le, nottate, insieme, ...
# 22  (LUCIA, (, Che, ha, rimesso, a, posto, le, sed...
# 26  (una, tazza, me, la, sono, presa, io, ,, un’, ...
# 29  (donna, Rosalia, il, caffè, non, l’, ha, fatto...
# 33        (E, perché, non, l’, ha, fatto, Rosalia, ?)
# 35  (Dice, che, doveva, portare, tre, lettere, urg...
#
#                                              entities   character_entities
# 3                                          [Domenico]           [Domenico]
# 6                                             [Lucia]              [Lucia]
# 11  [PRIMA, LUCIA, ALFREDO, ROSALIA, ALFREDO, Stan...              [Lucia]
# 15                      [Siede, Domenico, Caracciolo]           [Domenico]
# 21                                            [Lucia]              [Lucia]
# 22                                   [LUCIA, Alfredo]            [Alfredo]
# 26  [Rosalia, Filomena, don Domenico, ALFREDO, Fis...  [Rosalia, Filomena]
# 29                                          [Rosalia]            [Rosalia]
# 33                                          [Rosalia]            [Rosalia]
# 35                                         [Filomena]           [Filomena]

# %%
# Take only first name of characters
sent_entity_df_filtered['character_entities'] = sent_entity_df_filtered['character_entities'].apply(lambda x: [item.split()[0]
                                                                                                               for item in x])
# Out:
# C:\Users\Eleonora\AppData\Local\Temp\ipykernel_5460\1239962011.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sent_entity_df_filtered['character_entities'] = sent_entity_df_filtered['character_entities'].apply(lambda x: [item.split()[0]

# %%
pd.reset_option('^display.', silent=True)
sent_entity_df_filtered
# Out:
#                                               sentence  \
# 3    (qualcuna, portandola, sul, terrazzo, ,, altre...
# 6                   (Lucia, è, la, serva, di, casa, :)
# 11   (SCENA, PRIMA, \n, (, LUCIA, e, ALFREDO, ,, po...
# 15   (..., Io, sono, stanco, morto, !, (, Siede, pr...
# 21   (Non, posso, più, fare, le, nottate, insieme, ...
# ..                                                 ...
# 708  (..., (, Verso, lo, «, studio, », energica, ),...
# 710  ((, Chiamando, verso, sinistra, ), Rosalia, ,,...
# 714  ((, Dallo, «, studio, », compare, Nocella, ,, ...
# 717  ((, Dal, fondo, viene, anche, Lucia, ), Hai, c...
# 721  (Ne, strappa, un, pezzetto, ,, poi, a, Domenic...
#
#                                               entities character_entities
# 3                                           [Domenico]         [Domenico]
# 6                                              [Lucia]            [Lucia]
# 11   [PRIMA, LUCIA, ALFREDO, ROSALIA, ALFREDO, Stan...            [Lucia]
# 15                       [Siede, Domenico, Caracciolo]         [Domenico]
# 21                                             [Lucia]            [Lucia]
# ..                                                 ...                ...
# 708                  [Avvocato, Alludendo, Diana, Hai]  [Avvocato, Diana]
# 710                                          [Rosalia]          [Rosalia]
# 714                          [Nocella, Diana, Alfredo]   [Diana, Alfredo]
# 717                                  [Lucia, Domenico]  [Lucia, Domenico]
# 721                                         [Domenico]         [Domenico]
#
# [136 rows x 3 columns]

# %%
window_size = 5
relationships = []

for i in range(sent_entity_df_filtered.index[-1]):
    end_i = min(i+5, sent_entity_df_filtered.index[-1])
    char_list = sum((sent_entity_df_filtered.loc[i: end_i].character_entities), [])
    
    # Remove duplicated characters that are next to each other
    char_unique = [char_list[i] for i in range(len(char_list)) 
                   if (i==0) or char_list[i] != char_list[i-1]]
    
    if len(char_unique) > 1:
        for idx, a in enumerate(char_unique[:-1]):
            b = char_unique[idx + 1]
            relationships.append({"source": a, "target": b})

# %%
relationship_df = pd.DataFrame(relationships)

# %%
pd.set_option('display.max_rows', None)
relationship_df
# Out:
#        source    target
# 0    Domenico     Lucia
# 1    Domenico     Lucia
# 2    Domenico     Lucia
# 3       Lucia  Domenico
# 4       Lucia  Domenico
# 5       Lucia   Alfredo
# 6       Lucia   Alfredo
# 7       Lucia   Alfredo
# 8       Lucia   Alfredo
# 9       Lucia   Alfredo
# 10    Alfredo   Rosalia
# 11    Rosalia  Filomena
# 12    Alfredo   Rosalia
# 13    Rosalia  Filomena
# 14    Rosalia  Filomena
# 15    Rosalia  Filomena
# 16   Filomena   Rosalia
# 17    Rosalia  Filomena
# 18   Filomena   Rosalia
# 19    Rosalia  Filomena
# 20   Filomena   Rosalia
# 21    Rosalia  Filomena
# 22    Rosalia  Filomena
# 23    Rosalia  Filomena
# 24    Rosalia  Filomena
# 25    Rosalia   Alfredo
# 26    Rosalia   Alfredo
# 27    Rosalia   Alfredo
# 28    Alfredo   Rosalia
# 29    Rosalia   Alfredo
# 30    Alfredo   Rosalia
# 31    Rosalia   Alfredo
# 32    Alfredo   Rosalia
# 33    Rosalia   Alfredo
# 34    Alfredo   Rosalia
# 35    Rosalia     Lucia
# 36    Rosalia     Lucia
# 37      Lucia   Rosalia
# 38    Rosalia   Alfredo
# 39    Rosalia     Lucia
# 40      Lucia   Rosalia
# 41    Rosalia   Alfredo
# 42    Alfredo  Filomena
# 43      Lucia   Rosalia
# 44    Rosalia   Alfredo
# 45    Alfredo  Filomena
# 46   Filomena   Alfredo
# 47    Alfredo   Rosalia
# 48      Lucia   Rosalia
# 49    Rosalia   Alfredo
# 50    Alfredo  Filomena
# 51   Filomena   Alfredo
# 52    Alfredo   Rosalia
# 53      Lucia   Rosalia
# 54    Rosalia   Alfredo
# 55    Alfredo  Filomena
# 56   Filomena   Alfredo
# 57    Alfredo   Rosalia
# 58    Rosalia   Alfredo
# 59    Alfredo  Filomena
# 60   Filomena   Alfredo
# 61    Alfredo   Rosalia
# 62   Filomena   Alfredo
# 63    Alfredo   Rosalia
# 497     Diana   Alfredo
# 498     Diana   Alfredo
# 499     Diana   Alfredo
# 500   Alfredo     Lucia
# 501     Lucia  Domenico
# 502     Diana   Alfredo
# 503   Alfredo     Lucia
# 504     Lucia  Domenico
# 505     Diana   Alfredo
# 506   Alfredo     Lucia
# 507     Lucia  Domenico
# 508     Lucia  Domenico
# 509     Lucia  Domenico
# 510     Lucia  Domenico

# %%
# Sort the cases with a->b and b->a
relationship_df = pd.DataFrame(np.sort(relationship_df.values, axis = 1), columns = relationship_df.columns)
relationship_df
# Out:
#        source    target
# 0    Domenico     Lucia
# 1    Domenico     Lucia
# 2    Domenico     Lucia
# 3    Domenico     Lucia
# 4    Domenico     Lucia
# 5     Alfredo     Lucia
# 6     Alfredo     Lucia
# 7     Alfredo     Lucia
# 8     Alfredo     Lucia
# 9     Alfredo     Lucia
# 10    Alfredo   Rosalia
# 11   Filomena   Rosalia
# 12    Alfredo   Rosalia
# 13   Filomena   Rosalia
# 14   Filomena   Rosalia
# 15   Filomena   Rosalia
# 16   Filomena   Rosalia
# 17   Filomena   Rosalia
# 18   Filomena   Rosalia
# 19   Filomena   Rosalia
# 20   Filomena   Rosalia
# 21   Filomena   Rosalia
# 22   Filomena   Rosalia
# 23   Filomena   Rosalia
# 24   Filomena   Rosalia
# 25    Alfredo   Rosalia
# 26    Alfredo   Rosalia
# 27    Alfredo   Rosalia
# 28    Alfredo   Rosalia
# 29    Alfredo   Rosalia
# 30    Alfredo   Rosalia
# 31    Alfredo   Rosalia
# 32    Alfredo   Rosalia
# 33    Alfredo   Rosalia
# 34    Alfredo   Rosalia
# 35      Lucia   Rosalia
# 36      Lucia   Rosalia
# 37      Lucia   Rosalia
# 38    Alfredo   Rosalia
# 39      Lucia   Rosalia
# 40      Lucia   Rosalia
# 41    Alfredo   Rosalia
# 42    Alfredo  Filomena
# 43      Lucia   Rosalia
# 44    Alfredo   Rosalia
# 45    Alfredo  Filomena
# 46    Alfredo  Filomena
# 47    Alfredo   Rosalia
# 48      Lucia   Rosalia
# 49    Alfredo   Rosalia
# 50    Alfredo  Filomena
# 51    Alfredo  Filomena
# 52    Alfredo   Rosalia
# 53      Lucia   Rosalia
# 54    Alfredo   Rosalia
# 55    Alfredo  Filomena
# 56    Alfredo  Filomena
# 57    Alfredo   Rosalia
# 58    Alfredo   Rosalia
# 59    Alfredo  Filomena
# 60    Alfredo  Filomena
# 61    Alfredo   Rosalia
# 62    Alfredo  Filomena
# 63    Alfredo   Rosalia
# 64    Alfredo   Rosalia
# 65    Alfredo     Lucia
# 66    Alfredo     Lucia
# 67    Alfredo     Lucia
# 68    Alfredo     Lucia
# 69    Alfredo     Lucia
# 70    Alfredo     Lucia
# 71    Alfredo     Lucia
# 72    Alfredo     Lucia
# 73    Alfredo     Lucia
# 74    Alfredo     Lucia
# 75    Alfredo     Lucia
# 76    Alfredo     Lucia
# 77    Alfredo     Lucia
# 78   Domenico     Lucia
# 79    Alfredo     Lucia
# 80    Alfredo     Lucia
# 81   Domenico     Lucia
# 82    Alfredo     Lucia
# 83   Domenico     Lucia
# 1    Alfredo     Lucia     62
# 2    Alfredo   Rosalia     24
# 3   Filomena   Rosalia     38
# 4      Lucia   Rosalia     45
# 5    Alfredo  Filomena     22
# 6    Alfredo  Domenico      6
# 7   Domenico  Filomena     56
# 8   Domenico   Rosalia     10
# 9      Diana  Domenico     39
# 10     Diana  Filomena      4
# 11     Diana     Lucia      5
# 12  Filomena  Riccardo     10
# 13     Lucia  Riccardo     15
# 14     Lucia   Umberto     14
# 15  Riccardo   Umberto     35
# 16   Michele   Umberto     17
# 17     Lucia   Michele      2
# 18   Michele  Riccardo     12
# 19   Rosalia   Umberto      2
# 20  Domenico   Umberto      3
# 21  Avvocato  Filomena     20
# 22  Avvocato     Diana     10
# 23  Avvocato  Domenico      6
# 24  Filomena   Umberto      3
# 25  Filomena   Michele      5
# 26  Avvocato   Umberto      6
# 27  Avvocato   Rosalia      1
# 28     Diana   Rosalia      6
# 29   Alfredo     Diana      6

# %%
#relationship_df.to_csv
relationship_df.to_csv('output.csv', index=False, encoding='utf-8')

# %%
# Create a graph from a pandas dataframe
G = nx.from_pandas_edgelist(relationship_df, 
                            source = "source", 
                            target = "target", 
                            edge_attr = "value", 
                            create_using = nx.Graph())

# %%
plt.rcParams["figure.figsize"] = (5,5)
pos = nx.circular_layout(G)
nx.draw_networkx(G, with_labels=True, node_color='skyblue', edge_cmap=plt.cm.Blues, pos = pos)
plt.show()


#plt.rcParams["figure.figsize"] = (10,8)

# %%
from pyvis.network import Network
net = Network(notebook = True, width="1000px", height="700px", bgcolor='#ffffff', font_color='black')

node_degree = dict(G.degree)

#Setting up node size attribute
nx.set_node_attributes(G, node_degree, 'size')

net.from_nx(G)
net.show("Filumena.html")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# Filumena.html
#         <iframe
#             width="1000px"
#             height="700px"
#             src="Filumena.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Degree centrality
degree_dict = nx.degree_centrality(G)
degree_dict
#number of times the circles touches the edges is the degree
#in the dictionary we see that gandalf should be the largest node in our graph
# Out:
# {'Domenico': 0.7777777777777777,
#  'Lucia': 0.7777777777777777,
#  'Alfredo': 0.5555555555555556,
#  'Rosalia': 0.7777777777777777,
#  'Filomena': 0.8888888888888888,
#  'Diana': 0.6666666666666666,
#  'Riccardo': 0.4444444444444444,
#  'Umberto': 0.7777777777777777,
#  'Michele': 0.4444444444444444,
#  'Avvocato': 0.5555555555555556}

# %%
degree_df = pd.DataFrame.from_dict(degree_dict, orient='index', columns=['centrality'])
# Plot top 10 nodes
degree_df.sort_values('centrality', ascending=False).plot(kind="bar")
# Out:
# <Axes: >

# %%
import pandas as pd
import networkx as nx

# Assuming you have already created the graph G

# Calculate degree centrality
degree_dict = nx.degree_centrality(G)

# Create a DataFrame from the degree centrality dictionary
degree_df = pd.DataFrame.from_dict(degree_dict, orient='index', columns=['Centrality'])

# Sort the DataFrame by degree centrality in descending order
degree_df = degree_df.sort_values('Centrality', ascending=False)

# Reset the index to use the node IDs as a column
degree_df.reset_index(inplace=True)
degree_df = degree_df.rename(columns={'index': 'Node ID'})

# Display the DataFrame
print(degree_df)
# Out:
#     Node ID  Centrality
# 0  Filomena    0.888889
# 1  Domenico    0.777778
# 2     Lucia    0.777778
# 3   Rosalia    0.777778
# 4   Umberto    0.777778
# 5     Diana    0.666667
# 6   Alfredo    0.555556
# 7  Avvocato    0.555556
# 8  Riccardo    0.444444
# 9   Michele    0.444444

# %%
# Betweenness centrality
betweenness_dict = nx.betweenness_centrality(G)
betweenness_df = pd.DataFrame.from_dict(betweenness_dict, orient='index', columns=['centrality'])
# Plot top 10 nodes
betweenness_df.sort_values('centrality', ascending=False).plot(kind="bar")
# Out:
# <Axes: >

# %%
import pandas as pd
import networkx as nx

# Assuming you have already created the graph G

# Calculate degree centrality
degree_dict = nx.betweenness_centrality(G)

# Create a DataFrame from the degree centrality dictionary
degree_df = pd.DataFrame.from_dict(betweenness_dict, orient='index', columns=['Centrality'])

# Sort the DataFrame by degree centrality in descending order
degree_df = degree_df.sort_values('Centrality', ascending=False)

# Reset the index to use the node IDs as a column
degree_df.reset_index(inplace=True)
degree_df = degree_df.rename(columns={'index': 'Node ID'})

# Display the DataFrame
print(degree_df)
# Out:
#     Node ID  Centrality
# 0  Filomena    0.139815
# 1     Lucia    0.105093
# 2   Umberto    0.075728
# 3  Domenico    0.030357
# 4   Rosalia    0.030357
# 5     Diana    0.017857
# 6  Avvocato    0.005556
# 7   Alfredo    0.003968
# 8  Riccardo    0.003968
# 9   Michele    0.003968

# %%
# Closeness centrality
closeness_dict = nx.closeness_centrality(G)
closeness_df = pd.DataFrame.from_dict(closeness_dict, orient='index', columns=['centrality'])
# Plot top 10 nodes
closeness_df.sort_values('centrality', ascending=False).plot(kind="bar")
# Out:
# <Axes: >

# %%
import pandas as pd
import networkx as nx

# Assuming you have already created the graph G

# Calculate degree centrality
degree_dict = nx.closeness_centrality(G)

# Create a DataFrame from the degree centrality dictionary
degree_df = pd.DataFrame.from_dict(closeness_dict, orient='index', columns=['Centrality'])

# Sort the DataFrame by degree centrality in descending order
degree_df = degree_df.sort_values('Centrality', ascending=False)

# Reset the index to use the node IDs as a column
degree_df.reset_index(inplace=True)
degree_df = degree_df.rename(columns={'index': 'Node ID'})

# Display the DataFrame
print(degree_df)
# Out:
#     Node ID  Centrality
# 0  Filomena    0.900000
# 1  Domenico    0.818182
# 2     Lucia    0.818182
# 3   Rosalia    0.818182
# 4   Umberto    0.818182
# 5     Diana    0.750000
# 6   Alfredo    0.692308
# 7  Avvocato    0.692308
# 8  Riccardo    0.642857
# 9   Michele    0.642857

# %%
import community as community_louvain

# %%
communities = community_louvain.best_partition(G)

# %%
communities
# Out:
# {'Domenico': 1,
#  'Lucia': 1,
#  'Alfredo': 1,
#  'Rosalia': 1,
#  'Filomena': 0,
#  'Diana': 1,
#  'Riccardo': 0,
#  'Umberto': 0,
#  'Michele': 0,
#  'Avvocato': 1}

# %%
nx.set_node_attributes(G, communities, 'group')

# %%
com_net = Network(notebook = True, width="1000px", height="700px", bgcolor='#222222', font_color='white')
com_net.from_nx(G)
com_net.show("Filumena_communities.html")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# Filumena_communities.html
#         <iframe
#             width="1000px"
#             height="700px"
#             src="Filumena_communities.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
