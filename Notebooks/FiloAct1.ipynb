# %%
import pandas as pd
import numpy as np
import spacy
from spacy import displacy
import networkx as nx

import matplotlib.pyplot as plt

# %%
NER = spacy.load('it_core_news_sm')

# %%
script= 'data/FiloAct1.txt'
script_text = open(script, encoding='utf-8').read()
script_doc = NER(script_text)

# %%
displacy.render(script_doc[0:2000], style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">﻿ATTO
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PRIMO
# SCENA PRIMA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  </br>(
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DOMENICO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ALFREDO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FILOMENA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  e
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ROSALIA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) </br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DOMENICO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  (Schiaffeggiandosi ripetutamente con veemenza ed esasperazione)
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pazzo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , pazzo, pazzo! Cento volte, mille volte!
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ALFREDO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (Con un timido gesto interviene) Ma che fate?
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rosalia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  si avvicina a
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Filomena
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  e le pone sulle spalle uno scialle che avrà preso da una sedia sul fondo.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DOMENICO Io
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  sono un uomo da niente! Io devo mettermi di fronte allo specchio e non mi devo mai stancare di sputarmi in faccia. (Con un lampo di odio negli occhi a
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Filomena
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ) Con te, vicino a te ho sprecato la mia vita: venticinque anni di salute, di forza, d’intelligenza, di gioventù! Ma che alto vuoi? Che altro deve ancora dart
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Domenico Soriano
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# ? Anche di questa mia povera pelle, ne avete fatto quello che volevate! (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Inveendo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  contro tutti, come fuori di sé) Tutti hanno fatto quello che hanno voluto! (Contro sé stesso, con disprezzo) Mentre tu credevi di essere
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gesù Cristo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  sceso sulla terra, tutti ne facevano ciò che volevano, della tue pelle! (
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mostrando
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  un po’ tutti, con atto d’accusa) Tu, tu, tu… la gente del vicolo, del quartiere, di
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Napoli
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , del mondo…
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tutti mi hanno considerato
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  un fesso, sempre! (Il pensiero del tiro giuocatogli da
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Filomena
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  gli torna alla mente d’improvviso e gli fa ribollire il sangue) Io non posso pensarci… ma dovevo aspettarmelo! Solo una donna come te, poteva arrivare a tanto! Non putevi smentirti! Venticinque anni non potevano cambiarti! Ma non credere di aver vinto il punto: il punto non l’hai vinto!
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Io ti uccido
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  e ti pago tre soldi. Una donna come te non vale più di tre soldi! E a tutti quelli che ti hanno aiutata: il medico, il prete… (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mostrando Rosalia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  che trasale e
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-he

# %%
# Read characters
character_df = pd.read_csv("data/characters.csv")
#character_df

# %%
import re 
character_df['character'] = character_df['character'].apply(lambda x: re.sub("[\(].*?[\)]", "", x)) 
character_df['character_firstname'] = character_df['character'].apply(lambda x: x.split(' ', 1)[0])

# %%
sent_entity_df = []

# Loop through sentences, store named entity list for each sentence
for sent in script_doc.sents:
    entity_list = [ent.text for ent in sent.ents]
    sent_entity_df.append({"sentence": sent, "entities": entity_list})
    
sent_entity_df = pd.DataFrame(sent_entity_df)

# %%
sent_entity_df
# Out:
#                                               sentence  \
# 0    (﻿ATTO, PRIMO, \n, SCENA, PRIMA, \n, (, DOMENI...
# 1                   (Cento, volte, ,, mille, volte, !)
# 2    (ALFREDO, (, Con, un, timido, gesto, intervien...
# 3    (Rosalia, si, avvicina, a, Filomena, e, le, po...
# 4        (DOMENICO, Io, sono, un, uomo, da, niente, !)
# ..                                                 ...
# 529  ((, Siede, vicino, al, tavolo, di, fronte, al,...
# 530  (FILOMENA, (, Canticchia, ), «, Me, sto, crisc...
# 531               (Te, la, ricordi, questa, risata, …)
# 532                           (Filomena, Marturano, !)
# 533  (..., (, Ed, esce, seguito, da, Alfredo, ,, da...
#
#                                               entities
# 0    [PRIMO \nSCENA PRIMA, DOMENICO, ALFREDO, FILOM...
# 1                                                   []
# 2                                            [ALFREDO]
# 3                                  [Rosalia, Filomena]
# 4                                        [DOMENICO Io]
# ..                                                 ...
# 529  [Siede, DOMENICO Stammi, Filomena la napoletana!]
# 530  [FILOMENA, Canticchia, Me, nu bello cardillo, ...
# 531                                                 []
# 532                              [Filomena Marturano!]
# 533                                          [Alfredo]
#
# [534 rows x 2 columns]

# %%
# Function to filter out non-character entities
def filter_entity(ent_list, character_df):
    return [ent for ent in ent_list 
            if ent in list(character_df.character) 
            or ent in list(character_df.character_firstname)]

# %%
filter_entity(["Filomena", "Thu", "2"], character_df)
# Out:
# ['Filomena']

# %%
sent_entity_df['character_entities'] = sent_entity_df['entities'].apply(lambda x: filter_entity(x, character_df))

# Filter out sentences that don't have any character entities
sent_entity_df_filtered = sent_entity_df[sent_entity_df['character_entities'].map(len) > 0]
sent_entity_df_filtered.head(10)
# Out:
#                                              sentence  \
# 3   (Rosalia, si, avvicina, a, Filomena, e, le, po...
# 6   ((, Con, un, lampo, di, odio, negli, occhi, a,...
# 9   (Che, altro, deve, ancora, dart, Domenico, Sor...
# 13  ((, Il, pensiero, del, tiro, giuocatogli, da, ...
# 22  (il, medico, ,, il, prete, …, (, Mostrando, Ro...
# 28  (Mi, sono, svegliato, ,, ho, capito, !, ..., (...
# 29  (Non, c’, è, alcuna, legge, ,, non, c’, è, nes...
# 51  (Filomena, ,, ma, stai, dando, i, numeri, stas...
# 57  ((, Mostra, Alfredo, e, Rosalia, ), ROSALIA, (...
# 59  (DOMENICO, (, Ad, Alfredo, ), Tu, neanche, sai...
#
#                                              entities  \
# 3                                 [Rosalia, Filomena]
# 6                                          [Filomena]
# 9                                  [Domenico Soriano]
# 13                                         [Filomena]
# 22                       [Mostrando Rosalia, Alfredo]
# 28                          [Filomena, Tu te ne vai…]
# 29                            [Dio, Domenico Soriano]
# 51                                         [Filomena]
# 57  [Mostra, Alfredo, Rosalia, Pronta, Io non so n...
# 59                                [DOMENICO, Alfredo]
#
#               character_entities
# 3            [Rosalia, Filomena]
# 6                     [Filomena]
# 9             [Domenico Soriano]
# 13                    [Filomena]
# 22                     [Alfredo]
# 28                    [Filomena]
# 29            [Domenico Soriano]
# 51                    [Filomena]
# 57  [Alfredo, Rosalia, Filomena]
# 59                     [Alfredo]

# %%
# Take only first name of characters
sent_entity_df_filtered['character_entities'] = sent_entity_df_filtered['character_entities'].apply(lambda x: [item.split()[0]
                                                                                                               for item in x])
# Out:
# C:\Users\Eleonora\AppData\Local\Temp\ipykernel_10332\1239962011.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sent_entity_df_filtered['character_entities'] = sent_entity_df_filtered['character_entities'].apply(lambda x: [item.split()[0]

# %%
pd.reset_option('^display.', silent=True)
sent_entity_df_filtered
# Out:
#                                               sentence  \
# 3    (Rosalia, si, avvicina, a, Filomena, e, le, po...
# 6    ((, Con, un, lampo, di, odio, negli, occhi, a,...
# 9    (Che, altro, deve, ancora, dart, Domenico, Sor...
# 13   ((, Il, pensiero, del, tiro, giuocatogli, da, ...
# 22   (il, medico, ,, il, prete, …, (, Mostrando, Ro...
# ..                                                 ...
# 524  (..., (, Alfredo, fa, cenno, di, sì, col, capo...
# 527  (DOMENICO, Ti, faccio, conoscere, chi, è, Dome...
# 528  ((, Si, avvia, verso, il, fondo, ), FILOMENA, ...
# 530  (FILOMENA, (, Canticchia, ), «, Me, sto, crisc...
# 533  (..., (, Ed, esce, seguito, da, Alfredo, ,, da...
#
#                                               entities    character_entities
# 3                                  [Rosalia, Filomena]   [Rosalia, Filomena]
# 6                                           [Filomena]            [Filomena]
# 9                                   [Domenico Soriano]            [Domenico]
# 13                                          [Filomena]            [Filomena]
# 22                        [Mostrando Rosalia, Alfredo]             [Alfredo]
# ..                                                 ...                   ...
# 524                                          [Alfredo]             [Alfredo]
# 527                                 [Domenico Soriano]            [Domenico]
# 528                     [FILOMENA, Indicando, Rosalia]             [Rosalia]
# 530  [FILOMENA, Canticchia, Me, nu bello cardillo, ...  [Filomena, Filomena]
# 533                                          [Alfredo]             [Alfredo]
#
# [79 rows x 3 columns]

# %%
window_size = 5
relationships = []

for i in range(sent_entity_df_filtered.index[-1]):
    end_i = min(i+5, sent_entity_df_filtered.index[-1])
    char_list = sum((sent_entity_df_filtered.loc[i: end_i].character_entities), [])
    
    # Remove duplicated characters that are next to each other
    char_unique = [char_list[i] for i in range(len(char_list)) 
                   if (i==0) or char_list[i] != char_list[i-1]]
    
    if len(char_unique) > 1:
        for idx, a in enumerate(char_unique[:-1]):
            b = char_unique[idx + 1]
            relationships.append({"source": a, "target": b})

# %%
relationship_df = pd.DataFrame(relationships)

# %%
pd.set_option('display.max_rows', None)
relationship_df
# Out:
#        source    target
# 0     Rosalia  Filomena
# 1     Rosalia  Filomena
# 2     Rosalia  Filomena
# 3     Rosalia  Filomena
# 4    Filomena  Domenico
# 5    Filomena  Domenico
# 6    Filomena  Domenico
# 7    Domenico  Filomena
# 8    Domenico  Filomena
# 9    Filomena  Domenico
# 10   Filomena  Domenico
# 11   Filomena  Domenico
# 12   Filomena  Domenico
# 13   Filomena  Domenico
# 14    Alfredo   Rosalia
# 15    Rosalia  Filomena
# 16    Alfredo   Rosalia
# 17    Rosalia  Filomena
# 18    Alfredo   Rosalia
# 19    Rosalia  Filomena
# 20   Filomena   Alfredo
# 21    Alfredo   Rosalia
# 22    Rosalia  Filomena
# 23   Filomena   Alfredo
# 24    Alfredo   Rosalia
# 25    Rosalia  Filomena
# 26   Filomena   Alfredo
# 27    Alfredo   Rosalia
# 28    Rosalia  Filomena
# 29   Filomena   Alfredo
# 30    Alfredo  Filomena
# 153     Diana  Filomena
# 154   Alfredo  Domenico
# 155   Alfredo  Domenico
# 156   Alfredo  Domenico
# 157   Alfredo  Domenico
# 158   Alfredo  Domenico
# 159   Alfredo  Domenico
# 160   Alfredo  Domenico
# 161   Alfredo  Domenico
# 162   Alfredo  Domenico
# 163   Alfredo  Domenico
# 164   Alfredo  Domenico
# 165   Alfredo  Domenico
# 166  Domenico   Rosalia
# 167   Alfredo  Domenico
# 168  Domenico   Rosalia
# 169  Domenico   Rosalia
# 170  Filomena   Rosalia
# 171  Domenico   Rosalia
# 172  Filomena   Rosalia
# 173  Domenico   Rosalia
# 174  Filomena   Rosalia
# 175  Filomena   Rosalia
# 176   Alfredo  Filomena
# 177   Alfredo  Filomena
# 178   Alfredo  Filomena

# %%
relationship_df["value"] = 1
relationship_df = relationship_df.groupby(["source","target"], sort=False, as_index=False).sum()

# %%
relationship_df
# Out:
#      source    target  value
# 0  Filomena   Rosalia     26
# 1  Domenico  Filomena     31
# 2   Alfredo   Rosalia     38
# 3   Alfredo  Filomena     11
# 4   Alfredo  Domenico     17
# 5  Domenico   Rosalia     13
# 6  Riccardo   Umberto      1
# 7   Alfredo     Diana      5
# 8     Diana  Filomena     23
# 9     Diana  Domenico     14

# %%
#relationship_df.to_csv
relationship_df.to_csv('output.csv', index=False, encoding='utf-8')

# %%
# Create a graph from a pandas dataframe
G = nx.from_pandas_edgelist(relationship_df, 
                            source = "source", 
                            target = "target", 
                            edge_attr = "value", 
                            create_using = nx.Graph())

# %%
plt.rcParams["figure.figsize"] = (5,5)
pos = nx.circular_layout(G)
nx.draw_networkx(G, with_labels=True, node_color='skyblue', edge_cmap=plt.cm.Blues, pos = pos)
plt.show()


#plt.rcParams["figure.figsize"] = (10,8)

# %%
from pyvis.network import Network
net = Network(notebook = True, width="1000px", height="700px", bgcolor='#ffffff', font_color='black')

node_degree = dict(G.degree)

#Setting up node size attribute
nx.set_node_attributes(G, node_degree, 'size')

net.from_nx(G)
net.show("Filumena.html")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# Filumena.html
#         <iframe
#             width="1000px"
#             height="700px"
#             src="Filumena.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Degree centrality
degree_dict = nx.degree_centrality(G)
degree_dict
#number of times the circles touches the edges is the degree
#in the dictionary we see that gandalf should be the largest node in our graph
# Out:
# {'Filomena': 0.6666666666666666,
#  'Rosalia': 0.5,
#  'Domenico': 0.6666666666666666,
#  'Alfredo': 0.6666666666666666,
#  'Riccardo': 0.16666666666666666,
#  'Umberto': 0.16666666666666666,
#  'Diana': 0.5}

# %%
degree_df = pd.DataFrame.from_dict(degree_dict, orient='index', columns=['centrality'])
# Plot top 10 nodes
degree_df.sort_values('centrality', ascending=False).plot(kind="bar")
# Out:
# <Axes: >

# %%
import pandas as pd
import networkx as nx

# Assuming you have already created the graph G

# Calculate degree centrality
degree_dict = nx.degree_centrality(G)

# Create a DataFrame from the degree centrality dictionary
degree_df = pd.DataFrame.from_dict(degree_dict, orient='index', columns=['Centrality'])

# Sort the DataFrame by degree centrality in descending order
degree_df = degree_df.sort_values('Centrality', ascending=False)

# Reset the index to use the node IDs as a column
degree_df.reset_index(inplace=True)
degree_df = degree_df.rename(columns={'index': 'Node ID'})

# Display the DataFrame
print(degree_df)
# Out:
#     Node ID  Centrality
# 0  Filomena    0.666667
# 1  Domenico    0.666667
# 2   Alfredo    0.666667
# 3   Rosalia    0.500000
# 4     Diana    0.500000
# 5  Riccardo    0.166667
# 6   Umberto    0.166667

# %%
# Betweenness centrality
betweenness_dict = nx.betweenness_centrality(G)
betweenness_df = pd.DataFrame.from_dict(betweenness_dict, orient='index', columns=['centrality'])
# Plot top 10 nodes
betweenness_df.sort_values('centrality', ascending=False).plot(kind="bar")
# Out:
# <Axes: >

# %%
import pandas as pd
import networkx as nx

# Assuming you have already created the graph G

# Calculate degree centrality
degree_dict = nx.betweenness_centrality(G)

# Create a DataFrame from the degree centrality dictionary
degree_df = pd.DataFrame.from_dict(betweenness_dict, orient='index', columns=['Centrality'])

# Sort the DataFrame by degree centrality in descending order
degree_df = degree_df.sort_values('Centrality', ascending=False)

# Reset the index to use the node IDs as a column
degree_df.reset_index(inplace=True)
degree_df = degree_df.rename(columns={'index': 'Node ID'})

# Display the DataFrame
print(degree_df)
# Out:
#     Node ID  Centrality
# 0  Filomena    0.022222
# 1  Domenico    0.022222
# 2   Alfredo    0.022222
# 3   Rosalia    0.000000
# 4  Riccardo    0.000000
# 5   Umberto    0.000000
# 6     Diana    0.000000

# %%
# Closeness centrality
closeness_dict = nx.closeness_centrality(G)
closeness_df = pd.DataFrame.from_dict(closeness_dict, orient='index', columns=['centrality'])
# Plot top 10 nodes
closeness_df.sort_values('centrality', ascending=False).plot(kind="bar")
# Out:
# <Axes: >

# %%
import pandas as pd
import networkx as nx

# Assuming you have already created the graph G

# Calculate degree centrality
degree_dict = nx.closeness_centrality(G)

# Create a DataFrame from the degree centrality dictionary
degree_df = pd.DataFrame.from_dict(closeness_dict, orient='index', columns=['Centrality'])

# Sort the DataFrame by degree centrality in descending order
degree_df = degree_df.sort_values('Centrality', ascending=False)

# Reset the index to use the node IDs as a column
degree_df.reset_index(inplace=True)
degree_df = degree_df.rename(columns={'index': 'Node ID'})

# Display the DataFrame
print(degree_df)
# Out:
#     Node ID  Centrality
# 0  Filomena    0.666667
# 1  Domenico    0.666667
# 2   Alfredo    0.666667
# 3   Rosalia    0.533333
# 4     Diana    0.533333
# 5  Riccardo    0.166667
# 6   Umberto    0.166667

# %%
import community as community_louvain

# %%
communities = community_louvain.best_partition(G)

# %%
communities
# Out:
# {'Filomena': 1,
#  'Rosalia': 1,
#  'Domenico': 1,
#  'Alfredo': 1,
#  'Riccardo': 0,
#  'Umberto': 0,
#  'Diana': 1}

# %%
nx.set_node_attributes(G, communities, 'group')

# %%
com_net = Network(notebook = True, width="1000px", height="700px", bgcolor='#222222', font_color='white')
com_net.from_nx(G)
com_net.show("Filumena_communities.html")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# Filumena_communities.html
#         <iframe
#             width="1000px"
#             height="700px"
#             src="Filumena_communities.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
