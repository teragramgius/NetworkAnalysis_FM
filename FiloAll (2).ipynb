# %%
import pandas as pd
import numpy as np
import spacy
from spacy import displacy
import networkx as nx

import matplotlib.pyplot as plt

# %%
NER = spacy.load('it_core_news_sm')

# %%
script= 'data/Filumena.txt'
script_text = open(script, encoding='utf-8').read()
script_doc = NER(script_text)

# %%
displacy.render(script_doc[0:2000], style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">﻿ATTO
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PRIMO
# SCENA PRIMA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  </br>(
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DOMENICO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ALFREDO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FILOMENA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  e
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ROSALIA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) </br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DOMENICO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  (Schiaffeggiandosi ripetutamente con veemenza ed esasperazione)
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pazzo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , pazzo, pazzo! Cento volte, mille volte!
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ALFREDO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (Con un timido gesto interviene) Ma che fate?
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rosalia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  si avvicina a
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Filomena
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  e le pone sulle spalle uno scialle che avrà preso da una sedia sul fondo.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DOMENICO Io
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  sono un uomo da niente! Io devo mettermi di fronte allo specchio e non mi devo mai stancare di sputarmi in faccia. (Con un lampo di odio negli occhi a
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Filomena
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ) Con te, vicino a te ho sprecato la mia vita: venticinque anni di salute, di forza, d’intelligenza, di gioventù! Ma che alto vuoi? Che altro deve ancora dart
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Domenico Soriano
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# ? Anche di questa mia povera pelle, ne avete fatto quello che volevate! (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Inveendo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  contro tutti, come fuori di sé) Tutti hanno fatto quello che hanno voluto! (Contro sé stesso, con disprezzo) Mentre tu credevi di essere
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gesù Cristo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  sceso sulla terra, tutti ne facevano ciò che volevano, della tue pelle! (
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mostrando
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  un po’ tutti, con atto d’accusa) Tu, tu, tu… la gente del vicolo, del quartiere, di
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Napoli
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , del mondo…
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tutti mi hanno considerato
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  un fesso, sempre! (Il pensiero del tiro giuocatogli da
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Filomena
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  gli torna alla mente d’improvviso e gli fa ribollire il sangue) Io non posso pensarci… ma dovevo aspettarmelo! Solo una donna come te, poteva arrivare a tanto! Non putevi smentirti! Venticinque anni non potevano cambiarti! Ma non credere di aver vinto il punto: il punto non l’hai vinto!
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Io ti uccido
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  e ti pago tre soldi. Una donna come te non vale più di tre soldi! E a tutti quelli che ti hanno aiutata: il medico, il prete… (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mostrando Rosalia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  che trasale e
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-he

# %%
# Read characters
character_df = pd.read_csv("data/characters.csv")
#character_df

# %%
import re 
character_df['character'] = character_df['character'].apply(lambda x: re.sub("[\(].*?[\)]", "", x)) 
character_df['character_firstname'] = character_df['character'].apply(lambda x: x.split(' ', 1)[0])

# %%
sent_entity_df = []

# Loop through sentences, store named entity list for each sentence
for sent in script_doc.sents:
    entity_list = [ent.text for ent in sent.ents]
    sent_entity_df.append({"sentence": sent, "entities": entity_list})
    
sent_entity_df = pd.DataFrame(sent_entity_df)

# %%
sent_entity_df
# Out:
#                                                sentence  \
# 0     (﻿ATTO, PRIMO, \n, SCENA, PRIMA, \n, (, DOMENI...
# 1                    (Cento, volte, ,, mille, volte, !)
# 2     (ALFREDO, (, Con, un, timido, gesto, intervien...
# 3     (Rosalia, si, avvicina, a, Filomena, e, le, po...
# 4         (DOMENICO, Io, sono, un, uomo, da, niente, !)
# ...                                                 ...
# 1657  (Il, volto, le, si, riga, di, lacrime, come, a...
# 1658  (Domenico, preoccupato, le, si, avvicina, ), F...
# 1659  (FILOMENA, (, Felice, ), Domenico, ,, sto, pia...
# 1660  (Hai, corso, …, hai, corso, …, hai, avuto, pau...
# 1661  (..., (, E, tracanna, il, suo, vino, ,, mentre...
#
#                                                entities
# 0     [PRIMO \nSCENA PRIMA, DOMENICO, ALFREDO, FILOM...
# 1                                                    []
# 2                                             [ALFREDO]
# 3                                   [Rosalia, Filomena]
# 4                                         [DOMENICO Io]
# ...                                                 ...
# 1657                                                 []
# 1658                               [Domenico, Filomena]
# 1659  [FILOMENA, Felice, Domenico, DOMENICO, Stringe...
# 1660                 [Hai, Riposati!..., Hai, Filomena]
# 1661                           [E tracanna il suo vino]
#
# [1662 rows x 2 columns]

# %%
# Function to filter out non-character entities
def filter_entity(ent_list, character_df):
    return [ent for ent in ent_list 
            if ent in list(character_df.character) 
            or ent in list(character_df.character_firstname)]

# %%
filter_entity(["Filomena", "Thu", "2"], character_df)
# Out:
# ['Filomena']

# %%
sent_entity_df['character_entities'] = sent_entity_df['entities'].apply(lambda x: filter_entity(x, character_df))

# Filter out sentences that don't have any character entities
sent_entity_df_filtered = sent_entity_df[sent_entity_df['character_entities'].map(len) > 0]
sent_entity_df_filtered.head(10)
# Out:
#                                              sentence  \
# 3   (Rosalia, si, avvicina, a, Filomena, e, le, po...
# 6   ((, Con, un, lampo, di, odio, negli, occhi, a,...
# 9   (Che, altro, deve, ancora, dart, Domenico, Sor...
# 13  ((, Il, pensiero, del, tiro, giuocatogli, da, ...
# 22  (il, medico, ,, il, prete, …, (, Mostrando, Ro...
# 28  (Mi, sono, svegliato, ,, ho, capito, !, ..., (...
# 29  (Non, c’, è, alcuna, legge, ,, non, c’, è, nes...
# 51  (Filomena, ,, ma, stai, dando, i, numeri, stas...
# 57  ((, Mostra, Alfredo, e, Rosalia, ), ROSALIA, (...
# 59  (DOMENICO, (, Ad, Alfredo, ), Tu, neanche, sai...
#
#                                              entities  \
# 3                                 [Rosalia, Filomena]
# 6                                          [Filomena]
# 9                                  [Domenico Soriano]
# 13                                         [Filomena]
# 22                       [Mostrando Rosalia, Alfredo]
# 28                          [Filomena, Tu te ne vai…]
# 29                            [Dio, Domenico Soriano]
# 51                                         [Filomena]
# 57  [Mostra, Alfredo, Rosalia, Pronta, Io non so n...
# 59                                [DOMENICO, Alfredo]
#
#               character_entities
# 3            [Rosalia, Filomena]
# 6                     [Filomena]
# 9             [Domenico Soriano]
# 13                    [Filomena]
# 22                     [Alfredo]
# 28                    [Filomena]
# 29            [Domenico Soriano]
# 51                    [Filomena]
# 57  [Alfredo, Rosalia, Filomena]
# 59                     [Alfredo]

# %%
# Take only first name of characters
sent_entity_df_filtered['character_entities'] = sent_entity_df_filtered['character_entities'].apply(lambda x: [item.split()[0]
                                                                                                               for item in x])
# Out:
# C:\Users\Eleonora\AppData\Local\Temp\ipykernel_2108\1239962011.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sent_entity_df_filtered['character_entities'] = sent_entity_df_filtered['character_entities'].apply(lambda x: [item.split()[0]

# %%
pd.reset_option('^display.', silent=True)
sent_entity_df_filtered
# Out:
#                                                sentence  \
# 3     (Rosalia, si, avvicina, a, Filomena, e, le, po...
# 6     ((, Con, un, lampo, di, odio, negli, occhi, a,...
# 9     (Che, altro, deve, ancora, dart, Domenico, Sor...
# 13    ((, Il, pensiero, del, tiro, giuocatogli, da, ...
# 22    (il, medico, ,, il, prete, …, (, Mostrando, Ro...
# ...                                                 ...
# 1648  (I, TRE, (, Uscendo, seguiti, da, Alfredo, ,, ...
# 1649  (Domenico, li, ha, seguiti, con, lo, sguardo, ...
# 1658  (Domenico, preoccupato, le, si, avvicina, ), F...
# 1659  (FILOMENA, (, Felice, ), Domenico, ,, sto, pia...
# 1660  (Hai, corso, …, hai, corso, …, hai, avuto, pau...
#
#                                                entities  \
# 3                                   [Rosalia, Filomena]
# 6                                            [Filomena]
# 9                                    [Domenico Soriano]
# 13                                           [Filomena]
# 22                         [Mostrando Rosalia, Alfredo]
# ...                                                 ...
# 1648                 [Uscendo, Alfredo, Rosalia, Lucia]
# 1649                                         [Domenico]
# 1658                               [Domenico, Filomena]
# 1659  [FILOMENA, Felice, Domenico, DOMENICO, Stringe...
# 1660                 [Hai, Riposati!..., Hai, Filomena]
#
#              character_entities
# 3           [Rosalia, Filomena]
# 6                    [Filomena]
# 9                    [Domenico]
# 13                   [Filomena]
# 22                    [Alfredo]
# ...                         ...
# 1648  [Alfredo, Rosalia, Lucia]
# 1649                 [Domenico]
# 1658       [Domenico, Filomena]
# 1659                 [Domenico]
# 1660                 [Filomena]
#
# [283 rows x 3 columns]

# %%
window_size = 5
relationships = []

for i in range(sent_entity_df_filtered.index[-1]):
    end_i = min(i+5, sent_entity_df_filtered.index[-1])
    char_list = sum((sent_entity_df_filtered.loc[i: end_i].character_entities), [])
    
    # Remove duplicated characters that are next to each other
    char_unique = [char_list[i] for i in range(len(char_list)) 
                   if (i==0) or char_list[i] != char_list[i-1]]
    
    if len(char_unique) > 1:
        for idx, a in enumerate(char_unique[:-1]):
            b = char_unique[idx + 1]
            relationships.append({"source": a, "target": b})

# %%
relationship_df = pd.DataFrame(relationships)

# %%
pd.set_option('display.max_rows', None)
relationship_df
# Out:
#        source    target
# 0     Rosalia  Filomena
# 1     Rosalia  Filomena
# 2     Rosalia  Filomena
# 3     Rosalia  Filomena
# 4    Filomena  Domenico
# 5    Filomena  Domenico
# 6    Filomena  Domenico
# 7    Domenico  Filomena
# 8    Domenico  Filomena
# 9    Filomena  Domenico
# 10   Filomena  Domenico
# 11   Filomena  Domenico
# 12   Filomena  Domenico
# 13   Filomena  Domenico
# 14    Alfredo   Rosalia
# 15    Rosalia  Filomena
# 16    Alfredo   Rosalia
# 17    Rosalia  Filomena
# 18    Alfredo   Rosalia
# 19    Rosalia  Filomena
# 20   Filomena   Alfredo
# 21    Alfredo   Rosalia
# 22    Rosalia  Filomena
# 23   Filomena   Alfredo
# 24    Alfredo   Rosalia
# 25    Rosalia  Filomena
# 26   Filomena   Alfredo
# 27    Alfredo   Rosalia
# 28    Rosalia  Filomena
# 29   Filomena   Alfredo
# 30    Alfredo  Filomena
# 31    Alfredo  Filomena
# 32   Filomena  Domenico
# 33    Alfredo  Filomena
# 34   Filomena  Domenico
# 465     Lucia  Riccardo
# 466  Riccardo     Lucia
# 467  Riccardo     Lucia
# 468   Umberto     Lucia
# 469   Umberto     Lucia
# 470   Umberto     Lucia
# 471   Umberto     Lucia
# 472   Umberto     Lucia
# 473  Riccardo   Umberto
# 474   Umberto     Lucia
# 475  Riccardo   Umberto
# 476   Umberto     Lucia
# 477  Riccardo   Umberto
# 478   Umberto     Lucia
# 479  Riccardo   Umberto
# 480   Umberto     Lucia
# 481     Lucia   Umberto
# 482  Riccardo   Umberto
# 483   Umberto     Lucia
# 484     Lucia   Umberto
# 485   Umberto   Michele
# 486  Riccardo   Umberto
# 487   Umberto     Lucia
# 488     Lucia   Umberto
# 489   Umberto   Michele
# 490   Umberto   Michele
# 491   Umberto   Michele
# 492   Umberto   Michele
# 493   Michele     Lucia
# 494   Michele     Lucia
# 495  Filomena  Riccardo
# 496  Filomena  Riccardo
# 497  Filomena  Riccardo
# 498  Filomena  Riccardo
# 499  Filomena  Riccardo
# 500   Umberto  Riccardo
# 501   Umberto  Riccardo
# 502   Umberto  Riccardo
# 503   Umberto  Riccardo
# 504   Umberto  Riccardo
# 505   Umberto  Riccardo
# 506   Umberto  Riccardo
# 507  Riccardo   Umberto
# 508   Umberto  Riccardo
# 509  Riccardo   Umberto
# 510   Umberto   Michele
# 511   Michele  Riccardo
# 512  Riccardo   Umberto
# 513   Umberto  Riccardo
# 514  Riccardo   Umberto
# 515   Umberto   Michele
# 516   Michele  Riccardo
# 517  Riccardo   Umberto
# 518   Umberto  Riccardo
# 519  Riccardo   Umberto
# 520   Umberto   Michele
# 521   Michele  Riccardo
# 522  Riccardo   Umberto
# 523   Umberto  Riccardo
# 524  Riccardo   Umberto
# 525   Umberto   Michele
# 526   Michele  Riccardo
# 527  Riccardo   Umberto
# 528  Riccardo   Umberto
# 529   Umberto   Michele
# 530   Michele  Riccardo
# 531  Riccardo   Umberto
# 532   Umberto   Rosalia
# 533   Umberto   Michele
# 534   Michele  Riccardo
# 535  Riccardo   Umberto
# 536   Umberto   Rosalia
# 537  Filomena  Riccardo
# 538  Filomena  Riccardo
# 539  Filomena  Riccardo
# 540  Domenico   Umberto
# 541   Umberto   Michele
# 542  Domenico   Umberto
# 543   Umberto   Michele
# 544  Domenico   Umberto
# 545   Umberto   Michele
# 546   Umberto   Michele
# 547   Umberto   Michele
# 548   Umberto   Michele
# 549   Rosalia  Domenico
# 550   Rosalia  Domenico
# 551  Filomena  Avvocato
# 552  Filomena  Avvocato
# 553  Filomena  Avvocato
# 554  Avvocato     Diana
# 555  Filomena  Avvocato
# 556  Avvocato     Diana
# 557  Avvocato     Diana
# 558  Avvocato     Diana
# 559   Alfredo     Lucia
# 560     Lucia   Rosalia
# 561   Alfredo     Lucia
# 562     Lucia   Rosalia
# 563   Alfredo     Lucia
# 564     Lucia   Rosalia
# 565   Alfredo     Lucia
# 566     Lucia   Rosalia
# 567   Rosalia  Domenico
# 568  Domenico  Filomena
# 569   Alfredo     Lucia
# 570     Lucia   Rosalia
# 571   Rosalia  Domenico
# 572  Domenico  Filomena
# 573   Alfredo     Lucia
# 720   Michele  Riccardo
# 721   Michele  Riccardo
# 722  Domenico  Filomena
# 723  Domenico  Filomena
# 724  Domenico  Filomena
# 725  Domenico  Filomena
# 726  Domenico  Filomena
# 727   Michele  Riccardo
# 728   Michele  Riccardo
# 729   Michele  Riccardo
# 730   Michele  Riccardo
# 731  Domenico  Riccardo
# 732  Domenico  Riccardo
# 733  Domenico  Riccardo
# 734  Domenico  Riccardo
# 735  Domenico  Riccardo
# 736  Domenico  Riccardo
# 737  Riccardo   Umberto
# 738  Riccardo   Umberto
# 739   Michele  Riccardo
# 740  Riccardo   Umberto
# 741   Michele  Riccardo
# 742  Riccardo   Umberto
# 743   Michele  Riccardo
# 744  Riccardo   Umberto
# 745   Michele  Riccardo
# 746  Riccardo   Umberto
# 747   Michele  Riccardo
# 748   Michele  Riccardo
# 749   Michele  Riccardo
# 750   Michele   Umberto
# 751   Michele   Umberto
# 752   Michele  Riccardo
# 753   Michele   Umberto
# 754   Michele   Umberto
# 755   Michele  Riccardo
# 756   Michele   Umberto
# 757   Michele   Umberto
# 758   Michele   Umberto
# 759   Michele   Umberto
# 760   Michele   Umberto
# 761   Michele   Umberto
# 762   Michele   Umberto
# 763   Rosalia  Teresina
# 764     Lucia   Rosalia
# 765     Lucia  Teresina
# 766   Rosalia  Teresina
# 767     Lucia   Rosalia
# 768     Lucia  Teresina
# 769   Rosalia  Teresina
# 770     Lucia   Rosalia
# 771     Lucia  Teresina
# 772   Rosalia  Teresina
# 773     Lucia   Rosalia
# 774     Lucia  Teresina
# 775   Rosalia  Teresina
# 776     Lucia   Rosalia
# 777     Lucia  Teresina
# 778   Rosalia  Teresina
# 779     Lucia   Rosalia
# 780     Lucia  Teresina
# 781  Filomena  Teresina
# 782     Lucia   Rosalia
# 783     Lucia   Rosalia
# 784     Lucia   Rosalia
# 785     Lucia   Rosalia
# 786   Alfredo     Lucia
# 787   Alfredo   Rosalia
# 788   Alfredo     Lucia
# 789   Alfredo   Rosalia
# 790   Alfredo     Lucia
# 791   Alfredo   Rosalia
# 792   Alfredo     Lucia
# 793   Alfredo   Rosalia
# 794   Alfredo     Lucia
# 795   Alfredo   Rosalia
# 796   Alfredo   Rosalia
# 797  Filomena   Rosalia
# 798  Filomena  Riccardo
# 799  Filomena  Riccardo
# 800  Filomena  Riccardo
# 801  Riccardo   Umberto
# 802  Filomena  Riccardo
# 803  Riccardo   Umberto
# 804  Riccardo   Umberto
# 805  Domenico   Umberto
# 806  Riccardo   Umberto
# 807  Domenico   Umberto
# 808  Domenico   Umberto
# 809  Domenico   Umberto
# 810  Filomena  Riccardo
# 811  Filomena  Riccardo
# 812  Riccardo   Rosalia
# 813  Filomena  Riccardo
# 814  Riccardo   Rosalia
# 815  Filomena  Riccardo
# 816  Riccardo   Rosalia
# 817  Riccardo   Rosalia
# 818  Filomena  Riccardo
# 819  Riccardo   Rosalia
# 820  Riccardo   Rosalia
# 821  Riccardo   Rosalia
# 822  Filomena  Riccardo
# 823  Riccardo   Rosalia
# 824  Riccardo   Rosalia
# 825  Riccardo   Rosalia
# 3    Alfredo  Filomena     36
# 4    Alfredo  Domenico     31
# 5   Domenico   Rosalia     28
# 6   Riccardo   Umberto     52
# 7    Alfredo     Diana     11
# 8      Diana  Filomena     27
# 9      Diana  Domenico     53
# 10  Domenico     Lucia     32
# 11   Alfredo     Lucia     84
# 12     Lucia   Rosalia     61
# 13     Diana     Lucia      5
# 14  Filomena  Riccardo     20
# 15     Lucia  Riccardo     15
# 16     Lucia   Umberto     16
# 17   Michele   Umberto     34
# 18     Lucia   Michele      2
# 19   Michele  Riccardo     35
# 20   Rosalia   Umberto      2
# 21  Domenico   Umberto      7
# 22  Avvocato  Filomena     20
# 23  Avvocato     Diana     10
# 24  Avvocato  Domenico      6
# 25  Filomena   Umberto      5
# 26  Filomena   Michele      5
# 27  Avvocato   Umberto      6
# 28  Avvocato   Rosalia      1
# 29     Diana   Rosalia      6
# 30  Domenico  Riccardo      6
# 31   Rosalia  Teresina      6
# 32     Lucia  Teresina      6
# 33  Filomena  Teresina      1
# 34  Riccardo   Rosalia     14
# 35   Michele   Rosalia      6
# 36  Filomena     Lucia      8

# %%
relationship_df.to_csv('output.csv', index=False, encoding='utf-8')

# %%
# Crea grafico G
G = nx.from_pandas_edgelist(relationship_df, 
                            source = "source", 
                            target = "target", 
                            edge_attr = "value", 
                            create_using = nx.Graph())

# %%
plt.rcParams["figure.figsize"] = (5,5)
pos = nx.circular_layout(G)
nx.draw_networkx(G, with_labels=True, node_color='skyblue', edge_cmap=plt.cm.Blues, pos = pos)
plt.show()


#plt.rcParams["figure.figsize"] = (10,8)

# %%
from pyvis.network import Network
net = Network(notebook = True, width="1000px", height="700px", bgcolor='#ffffff', font_color='black')

node_degree = dict(G.degree)

#Setting up node size attribute
nx.set_node_attributes(G, node_degree, 'size')

net.from_nx(G)
net.show("Filumena.html")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# Filumena.html
#         <iframe
#             width="1000px"
#             height="700px"
#             src="Filumena.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Degree centrality
degree_dict = nx.degree_centrality(G)
degree_dict
# Out:
# {'Filomena': 1.0,
#  'Rosalia': 1.0,
#  'Domenico': 0.8,
#  'Alfredo': 0.5,
#  'Riccardo': 0.6000000000000001,
#  'Umberto': 0.7000000000000001,
#  'Diana': 0.6000000000000001,
#  'Lucia': 0.9,
#  'Michele': 0.5,
#  'Avvocato': 0.5,
#  'Teresina': 0.30000000000000004}

# %%
degree_df = pd.DataFrame.from_dict(degree_dict, orient='index', columns=['centrality'])

degree_df.sort_values('centrality', ascending=False).plot(kind="bar")
# Out:
# <Axes: >

# %%
import pandas as pd
import networkx as nx


# Calculate degree centrality
degree_dict = nx.degree_centrality(G)

# Create a DataFrame from the degree centrality dictionary
degree_df = pd.DataFrame.from_dict(degree_dict, orient='index', columns=['Centrality'])

# Sort the DataFrame by degree centrality in descending order
degree_df = degree_df.sort_values('Centrality', ascending=False)

# Reset the index to use the node IDs as a column
degree_df.reset_index(inplace=True)
degree_df = degree_df.rename(columns={'index': 'Node ID'})

# Display the DataFrame
print(degree_df)
# Out:
#      Node ID  Centrality
# 0   Filomena         1.0
# 1    Rosalia         1.0
# 2      Lucia         0.9
# 3   Domenico         0.8
# 4    Umberto         0.7
# 5   Riccardo         0.6
# 6      Diana         0.6
# 7    Alfredo         0.5
# 8    Michele         0.5
# 9   Avvocato         0.5
# 10  Teresina         0.3

# %%
# Betweenness centrality
betweenness_dict = nx.betweenness_centrality(G)
betweenness_df = pd.DataFrame.from_dict(betweenness_dict, orient='index', columns=['centrality'])

betweenness_df.sort_values('centrality', ascending=False).plot(kind="bar")
# Out:
# <Axes: >

# %%
import pandas as pd
import networkx as nx

# Assuming you have already created the graph G

# Calculate degree centrality
degree_dict = nx.betweenness_centrality(G)

# Create a DataFrame from the degree centrality dictionary
degree_df = pd.DataFrame.from_dict(betweenness_dict, orient='index', columns=['Centrality'])

# Sort the DataFrame by degree centrality in descending order
degree_df = degree_df.sort_values('Centrality', ascending=False)

# Reset the index to use the node IDs as a column
degree_df.reset_index(inplace=True)
degree_df = degree_df.rename(columns={'index': 'Node ID'})

# Display the DataFrame
print(degree_df)
# Out:
#      Node ID  Centrality
# 0   Filomena    0.118889
# 1    Rosalia    0.118889
# 2      Lucia    0.084815
# 3   Domenico    0.036667
# 4    Umberto    0.021852
# 5      Diana    0.010000
# 6   Riccardo    0.004444
# 7   Avvocato    0.004444
# 8    Alfredo    0.000000
# 9    Michele    0.000000
# 10  Teresina    0.000000

# %%
# Closeness centrality
closeness_dict = nx.closeness_centrality(G)
closeness_df = pd.DataFrame.from_dict(closeness_dict, orient='index', columns=['centrality'])
# Plot top 10 nodes
closeness_df.sort_values('centrality', ascending=False).plot(kind="bar")
# Out:
# <Axes: >

# %%
import pandas as pd
import networkx as nx

# Assuming you have already created the graph G

# Calculate degree centrality
degree_dict = nx.closeness_centrality(G)

# Create a DataFrame from the degree centrality dictionary
degree_df = pd.DataFrame.from_dict(closeness_dict, orient='index', columns=['Centrality'])

# Sort the DataFrame by degree centrality in descending order
degree_df = degree_df.sort_values('Centrality', ascending=False)

# Reset the index to use the node IDs as a column
degree_df.reset_index(inplace=True)
degree_df = degree_df.rename(columns={'index': 'Node ID'})

# Display the DataFrame
print(degree_df)
# Out:
#      Node ID  Centrality
# 0   Filomena    1.000000
# 1    Rosalia    1.000000
# 2      Lucia    0.909091
# 3   Domenico    0.833333
# 4    Umberto    0.769231
# 5   Riccardo    0.714286
# 6      Diana    0.714286
# 7    Alfredo    0.666667
# 8    Michele    0.666667
# 9   Avvocato    0.666667
# 10  Teresina    0.588235

# %%
import community as community_louvain

# %%
communities = community_louvain.best_partition(G)

# %%
communities
# Out:
# {'Filomena': 0,
#  'Rosalia': 1,
#  'Domenico': 1,
#  'Alfredo': 1,
#  'Riccardo': 0,
#  'Umberto': 0,
#  'Diana': 1,
#  'Lucia': 0,
#  'Michele': 0,
#  'Avvocato': 1,
#  'Teresina': 0}

# %%
nx.set_node_attributes(G, communities, 'group')

# %%
com_net = Network(notebook = True, width="1000px", height="700px", bgcolor='#222222', font_color='white')
com_net.from_nx(G)
com_net.show("Filumena_communities.html")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# Filumena_communities.html
#         <iframe
#             width="1000px"
#             height="700px"
#             src="Filumena_communities.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
